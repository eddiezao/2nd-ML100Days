# %%
import os
import numpy as np
import pandas as pd

direction_data = './data/'
a_app = os.path.join(direction_data,'application_train.csv')
print('path of read on data:%s'%(a_app))
df = pd.read_csv(a_app)

df.head(3) #顯示前三組資料
# Out:
# path of read on data:./data/application_train.csv
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# 0             ...                             0                0
# 1             ...                             0                0
# 2             ...                             0                0
#
#   FLAG_DOCUMENT_20 FLAG_DOCUMENT_21 AMT_REQ_CREDIT_BUREAU_HOUR  \
# ...

# %%
df.shape #顯示所有(rows,columns)
# Out:
# (307511, 122)

# %%
df[['SK_ID_CURR','TARGET']][0:10]
# Out:
#    SK_ID_CURR  TARGET
# 0      100002       1
# 1      100003       0
# 2      100004       0
# 3      100006       0
# 4      100007       0
# 5      100008       0
# 6      100009       0
# 7      100010       0
# 8      100011       0
# 9      100012       0

# %%
df.insert(2,column='eddie',value='handsome')  #新增資料
df.head()
# Out:
#    SK_ID_CURR  TARGET     eddie NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1  handsome         Cash loans           M            N
# 1      100003       0  handsome         Cash loans           F            N
# 2      100004       0  handsome    Revolving loans           M            Y
# 3      100006       0  handsome         Cash loans           F            N
# 4      100007       0  handsome         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0               Y             0          202500.0    406597.5
# 1               N             0          270000.0   1293502.5
# 2               Y             0           67500.0    135000.0
# 3               Y             0          135000.0    312682.5
# 4               Y             0          121500.0    513000.0
#
#               ...              FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# ...
